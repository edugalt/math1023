# %% [markdown]
# # MATH 1023, Week 5

# %% [markdown]
# ## Lecturer: Eduardo G. Altmann,  http://www.maths.usyd.edu.au/u/ega/

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML

# %%
# Some functions    
def init():
    line.set_data([], [])
    line2.set_data([],[])
    time_text.set_text('')
    return line, time_text


def animate(i):
    thisx = [xh[i],0]
    thisy = [yh[i],0]

    line.set_data(thisx, thisy)
    line2.set_data([-0.05,-0.05],[-1,1])
    line3.set_data([1,1],[-2,-0.4])
    time_text.set_text(time_template % (i*dt))
    return line, time_text

# %% [markdown]
# ## Damped Harmonic Oscillator
# $$\frac{d^2x}{dt^2}+2\gamma \frac{dx}{dt}+\omega^2 x=0$$
#
# with $\gamma,\omega>0$

# %% [markdown]
# ### Case 0 (Harmonic Oscillator): $\gamma =0$

# %%
gamma=0
omega=2
kappa = np.sqrt(np.absolute(gamma**2-omega**2))

dt=0.05
N=200
yh=[];xh=[];th=[];
ones=np.power(1,np.zeros(N))

for i in range(N):
    t=i*dt
    th.append(t)
    yh.append(0)
    xh.append(1+0.8*np.exp(-gamma*t)*np.cos(kappa*t))

plt.plot(th,xh-ones)
plt.xlabel("time t")
plt.ylabel("position x")

# Animation
    
fig = plt.figure()
ax = fig.add_subplot(111, xlim=(-0.2, 2), ylim=(-1, 1),yticks=[],xticks=[])
ax.grid()

line, = ax.plot([], [], 'o-', lw=25,c="orange",ls=":",ms=50,marker="s",mfc="gray",fillstyle="none",mec="black",markevery=2)
line2,=ax.plot([],[],lw=20,c="black")
line3,=ax.plot([],[],lw=2,c="black",marker="^")
time_template = 'Damped Harmonic Oscillator,\n  K='+str(kappa)[:2]+', Damping $\gamma$='+str(gamma)[:2]+', Freq. w^2='+str(omega*omega)[:4]+'\n time = %.1fs'
time_text = ax.text(0.25, 0.9, '', transform=ax.transAxes)

ani = animation.FuncAnimation(fig, animate, np.arange(1, N),interval=50, blit=True, init_func=init,repeat=False)
HTML(ani.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### Case 1 (supercritical damping): $\gamma > \omega$

# %%
gamma=1.8
omega=1
kappa = np.sqrt(np.absolute(gamma**2-omega**2))

dt=0.05
N=200
yh=[];xh=[];th=[];
ones=np.power(1,np.zeros(N))
for i in range(N):
    t=i*dt
    th.append(t)
    yh.append(0)
    xh.append(1+np.exp(-gamma*t)*(0.5*np.exp(kappa*t)+0.5*np.exp(-kappa*t)))
    
#Plot
plt.plot(th,xh-ones)
plt.xlabel("time t")
plt.ylabel("position x")
#plt.show()

# Animation
fig = plt.figure()
ax = fig.add_subplot(111, xlim=(-0.2, 2), ylim=(-1, 1),yticks=[],xticks=[])
ax.grid()

line, = ax.plot([], [], 'o-', lw=25,c="orange",ls=":",ms=50,marker="s",mfc="gray",fillstyle="none",mec="black",markevery=2)
line2,=ax.plot([],[],lw=20,c="black")
line3,=ax.plot([],[],lw=2,c="black",marker="^")
time_template = 'Damped Harmonic Oscillator,\n  K='+str(kappa)[:2]+', Damping $\gamma$='+str(gamma)[:2]+', Freq. w^2='+str(omega*omega)[:4]+'\n time = %.1fs'
time_text = ax.text(0.25, 0.9, '', transform=ax.transAxes)

ani = animation.FuncAnimation(fig, animate, np.arange(1, N),interval=50, blit=True, init_func=init,repeat=False)
HTML(ani.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### Case 2 (subcritical damping): γ<ω

# %%
gamma=0.3
omega=2
kappa = np.sqrt(np.absolute(gamma**2-omega**2))

dt=0.05
N=200
yh=[];xh=[];th=[];
ones=np.power(1,np.zeros(N))

for i in range(N):
    t=i*dt
    th.append(t)
    yh.append(0)
    xh.append(1+0.8*np.exp(-gamma*t)*np.cos(kappa*t))

plt.plot(th,xh-ones)
plt.xlabel("time t")
plt.ylabel("position x")

# Animation
    
fig = plt.figure()
ax = fig.add_subplot(111, xlim=(-0.2, 2), ylim=(-1, 1),yticks=[],xticks=[])
ax.grid()

line, = ax.plot([], [], 'o-', lw=25,c="orange",ls=":",ms=50,marker="s",mfc="gray",fillstyle="none",mec="black",markevery=2)
line2,=ax.plot([],[],lw=20,c="black")
line3,=ax.plot([],[],lw=2,c="black",marker="^")
time_template = 'Damped Harmonic Oscillator,\n  K='+str(kappa)[:2]+', Damping $\gamma$='+str(gamma)[:2]+', Freq. w^2='+str(omega*omega)[:4]+'\n time = %.1fs'
time_text = ax.text(0.25, 0.9, '', transform=ax.transAxes)

ani = animation.FuncAnimation(fig, animate, np.arange(1, N),interval=50, blit=True, init_func=init,repeat=False)
HTML(ani.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### Case 3 $\gamma = \omega$

# %%
gamma=0.5
omega=gamma
kappa = np.sqrt(np.absolute(gamma**2-omega**2))

dt=0.05
N=200
yh=[]
xh=[]
th=[]
ones=np.power(1,np.zeros(N))

for i in range(N):
    t=i*dt
    th.append(t)
    yh.append(0)
    xh.append(1+np.exp(-gamma*t)*(1+0.2*t))

#Plot

plt.plot(th,xh-ones)
plt.xlabel("time t")
plt.ylabel("position x")
# Animation
    
fig = plt.figure()
ax = fig.add_subplot(111, xlim=(-0.2, 2), ylim=(-1, 1),yticks=[],xticks=[])
ax.grid()

line, = ax.plot([], [], 'o-', lw=25,c="orange",ls=":",ms=50,marker="s",mfc="gray",fillstyle="none",mec="black",markevery=2)
line2,=ax.plot([],[],lw=20,c="black")
line3,=ax.plot([],[],lw=2,c="black",marker="^")
time_template = 'Damped Harmonic Oscillator,\n  K='+str(kappa)[:2]+', Damping $\gamma$='+str(gamma)[:2]+', Freq. w^2='+str(omega*omega)[:4]+'\n time = %.1fs'
time_text = ax.text(0.25, 0.9, '', transform=ax.transAxes)


   
ani = animation.FuncAnimation(fig, animate, np.arange(1, N),
                              interval=50, blit=True, init_func=init,repeat=False)

HTML(ani.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-aab598e4a377> in <module>()
#       1 gamma=0.5
#       2 omega=gamma
# ----> 3 kappa = np.sqrt(np.absolute(gamma**2-omega**2))
#       4
#       5 dt=0.05
#
# NameError: name 'np' is not defined

# %% [markdown]
# # Parameter analysis
#
# restart kernal to work!

# %%
# %matplotlib notebook
from pylab import *
import numpy as np


from matplotlib.widgets import Slider,Button, RadioButtons

# %%
fig, ax = plt.subplots()
plt.subplots_adjust(left=0.25, bottom=0.25)
t = np.arange(0.0, 20.0, 0.001)
w=3
gamma=0
phi=0
A=1


s = A*np.cos(w*t+phi)
l, = plt.plot(t, s, lw=2, color='red')
plt.axis([0, 20, -5, 5])

axcolor = 'lightgoldenrodyellow'
axfreq = plt.axes([0.25, 0.15, 0.65, 0.03], axisbg=axcolor)
axA = plt.axes([0.25, 0.1, 0.65, 0.03], axisbg=axcolor)
axphi = plt.axes([0.25, 0.05, 0.65, 0.03], axisbg=axcolor)



sfreq = Slider(axfreq, 'Freq $\omega$', 0.01, 10.0, valinit=w)
sA = Slider(axA, '$A$ ', 0.0, 5.0, valinit=A)
sphi = Slider(axphi, '$\phi$', -3.1415, 3.1415, valinit=phi)


def update(val):
    A=sA.val
    phi=sphi.val
    gamma=sgamma.val
    w = sfreq.val
    l.set_ydata(A*np.cos(w*t+phi))
    fig.canvas.draw_idle()

sfreq.on_changed(update)
sA.on_changed(update)
sphi.on_changed(update)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="431.75000000000006">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-b14171e9a8a9> in <module>()
#      13
#      14 axcolor = 'lightgoldenrodyellow'
# ---> 15 axfreq = plt.axes([0.25, 0.15, 0.65, 0.03], axisbg=axcolor)
#      16 axA = plt.axes([0.25, 0.1, 0.65, 0.03], axisbg=axcolor)
#      17 axphi = plt.axes([0.25, 0.05, 0.65, 0.03], axisbg=axcolor)
#
# /usr/lib/python3.7/site-packages/matplotlib/pyplot.py in axes(arg, **kwargs)
#     936     else:
#     937         rect = arg
# --> 938         return gcf().add_axes(rect, **kwargs)
#     939
#     940
#
# /usr/lib/python3.7/site-packages/matplotlib/figure.py in add_axes(self, *args, **kwargs)
#    1134
#    1135             # create the new axes using the axes class given
# -> 1136             a = projection_class(self, rect, **kwargs)
#    1137
#    1138         self._axstack.add(key, a)
#
# /usr/lib/python3.7/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     537
#     538         if len(kwargs):
# --> 539             self.update(kwargs)
#     540
#     541         if self.xaxis is not None:
#
# /usr/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# /usr/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# /usr/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     879                 func = getattr(self, 'set_' + k, None)
#     880                 if not callable(func):
# --> 881                     raise AttributeError('Unknown property %s' % k)
#     882                 return func(v)
#     883
#
# AttributeError: Unknown property axisbg
# <img src="data:image/png;base64,..." width="431.75000000000006">

# %% [markdown]
# $$ \ddot{x} +  \omega^2 x = 0 $$
#
# $$ x(t) = A \cos(\omega t + \phi) $$

# %% [markdown]
# # Forced Damped Oscillators - Resonance

# %% [markdown]
# $$ \ddot{x} + 2\gamma \dot{x} + \omega^2 x = F \cos(\omega_F t)$$

# %%
fig, ax = plt.subplots()
plt.subplots_adjust(left=0.25, bottom=0.25)
t = np.arange(0.0, 20.0, 0.001)
#a0 = 5
#f0 = 0.2
phi=0

x0=1
v0=0
w=0.2
gamma=0.2

f=1
wf=1

f=1/np.sqrt((2*w*gamma**2)+(w**2-wf**2)**2)


A=np.sqrt(x0**2+(v0/w)**2)
phi=np.arccos(x0/A)

s = A*np.exp(-gamma*t)*np.cos(2*np.pi*np.sqrt(gamma**2-w**2)*t+phi) + f*np.sin(2*np.pi*wf*t)
l, = plt.plot(t, s, lw=2, color='red')
plt.axis([0, 20, -5, 5])

axcolor = 'lightgoldenrodyellow'
axfreq = plt.axes([0.25, 0.15, 0.65, 0.03], axisbg=axcolor)
axgamma = plt.axes([0.25, 0.1, 0.65, 0.03], axisbg=axcolor)

axx0 = plt.axes([0.25, 0.05, 0.65, 0.03], axisbg=axcolor)
axv0 = plt.axes([0.25, 0.0, 0.65, 0.03], axisbg=axcolor)



sfreq = Slider(axfreq, 'Freq $\omega$', 0.01, 2.0, valinit=w)
sgamma = Slider(axgamma, 'Damp $\gamma$', -1, 3.0, valinit=gamma)
sx0 = Slider(axx0, 'Init Pos $x(0)$', -1.0, 1.0, valinit=x0)
sv0 = Slider(axv0, 'Init Vel $v(0)$', -1.0, 1.0, valinit=v0)


def update(val):
    x0=sx0.val
    v0=sv0.val
    gamma=sgamma.val
    w = sfreq.val
    A=np.sqrt(x0**2+(v0/w)**2)
    phi=-np.sign(v0)*np.arccos(x0/A)  
    f=1/np.sqrt((2*w*gamma)**2+(w**2-wf**2)**2)
#    l.set_ydata(amp*np.sin(2*np.pi*freq*t))
    l.set_ydata(A*np.exp(-gamma*t)*np.cos(2*np.pi*np.sqrt(np.absolute(gamma**2-w**2))*t+phi)+f*np.sin(2*np.pi*wf*t))
    fig.canvas.draw_idle()

sfreq.on_changed(update)
sx0.on_changed(update)
sv0.on_changed(update)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9166666666667">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-10108ec32402> in <module>()
#      25
#      26 axcolor = 'lightgoldenrodyellow'
# ---> 27 axfreq = plt.axes([0.25, 0.15, 0.65, 0.03], axisbg=axcolor)
#      28 axgamma = plt.axes([0.25, 0.1, 0.65, 0.03], axisbg=axcolor)
#      29
#
# /usr/lib/python3.7/site-packages/matplotlib/pyplot.py in axes(arg, **kwargs)
#     936     else:
#     937         rect = arg
# --> 938         return gcf().add_axes(rect, **kwargs)
#     939
#     940
#
# /usr/lib/python3.7/site-packages/matplotlib/figure.py in add_axes(self, *args, **kwargs)
#    1134
#    1135             # create the new axes using the axes class given
# -> 1136             a = projection_class(self, rect, **kwargs)
#    1137
#    1138         self._axstack.add(key, a)
#
# /usr/lib/python3.7/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     537
#     538         if len(kwargs):
# --> 539             self.update(kwargs)
#     540
#     541         if self.xaxis is not None:
#
# /usr/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# /usr/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# /usr/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     879                 func = getattr(self, 'set_' + k, None)
#     880                 if not callable(func):
# --> 881                     raise AttributeError('Unknown property %s' % k)
#     882                 return func(v)
#     883
#
# AttributeError: Unknown property axisbg

# %% [markdown]
# #  Amplitude of oscillation as a function of ratio of frequencies: Resonance Curve

# %%
w = np.arange(0.1, 3.0, 0.001)
phi=0

x0=1
v0=0

gamma=0.1
wf=1
#a0 = 5
#f0 = 0.2
phi=0




f=np.divide(1,np.sqrt((2*w*gamma)**2+(w**2-wf**2)**2))
f2=np.divide(1,2*(w**2-wf**2)**2)


# %matplotlib inline

plt.ylim(0,6)
plt.plot(w,f,label="Damping")
plt.plot(w,f2,label="No damping")
plt.ylabel("Amplitude of the Oscillation")
plt.xlabel("natural frequency / forcing frequency = $\omega_f / \omega_0$")
plt.legend()
plt.show()
